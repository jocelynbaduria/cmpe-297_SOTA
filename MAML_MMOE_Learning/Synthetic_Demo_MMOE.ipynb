# %% [markdown]
# <a href="https://colab.research.google.com/github/jocelynbaduria/cmpe-297_SOTA/blob/main/Synthetic_Demo_MMOE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone 'https://github.com/drawbridge/keras-mmoe.git'
# Out:
# Cloning into 'keras-mmoe'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 61 (delta 9), reused 2 (delta 1), pack-reused 37
# Unpacking objects: 100% (61/61), done.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn

# %%
"""
Multi-gate Mixture-of-Experts model implementation.
Copyright (c) 2018 Drawbridge, Inc
Licensed under the MIT License (see LICENSE for details)
Written by Alvin Deng
"""

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import activations, initializers, regularizers, constraints
from tensorflow.keras.layers import Layer, InputSpec


class MMoE(Layer):
    """
    Multi-gate Mixture-of-Experts model.
    """

    def __init__(self,
                 units,
                 num_experts,
                 num_tasks,
                 use_expert_bias=True,
                 use_gate_bias=True,
                 expert_activation='relu',
                 gate_activation='softmax',
                 expert_bias_initializer='zeros',
                 gate_bias_initializer='zeros',
                 expert_bias_regularizer=None,
                 gate_bias_regularizer=None,
                 expert_bias_constraint=None,
                 gate_bias_constraint=None,
                 expert_kernel_initializer='VarianceScaling',
                 gate_kernel_initializer='VarianceScaling',
                 expert_kernel_regularizer=None,
                 gate_kernel_regularizer=None,
                 expert_kernel_constraint=None,
                 gate_kernel_constraint=None,
                 activity_regularizer=None,
                 **kwargs):
        """
         Method for instantiating MMoE layer.
        :param units: Number of hidden units
        :param num_experts: Number of experts
        :param num_tasks: Number of tasks
        :param use_expert_bias: Boolean to indicate the usage of bias in the expert weights
        :param use_gate_bias: Boolean to indicate the usage of bias in the gate weights
        :param expert_activation: Activation function of the expert weights
        :param gate_activation: Activation function of the gate weights
        :param expert_bias_initializer: Initializer for the expert bias
        :param gate_bias_initializer: Initializer for the gate bias
        :param expert_bias_regularizer: Regularizer for the expert bias
        :param gate_bias_regularizer: Regularizer for the gate bias
        :param expert_bias_constraint: Constraint for the expert bias
        :param gate_bias_constraint: Constraint for the gate bias
        :param expert_kernel_initializer: Initializer for the expert weights
        :param gate_kernel_initializer: Initializer for the gate weights
        :param expert_kernel_regularizer: Regularizer for the expert weights
        :param gate_kernel_regularizer: Regularizer for the gate weights
        :param expert_kernel_constraint: Constraint for the expert weights
        :param gate_kernel_constraint: Constraint for the gate weights
        :param activity_regularizer: Regularizer for the activity
        :param kwargs: Additional keyword arguments for the Layer class
        """
        # Hidden nodes parameter
        self.units = units
        self.num_experts = num_experts
        self.num_tasks = num_tasks

        # Weight parameter
        self.expert_kernels = None
        self.gate_kernels = None
        self.expert_kernel_initializer = initializers.get(expert_kernel_initializer)
        self.gate_kernel_initializer = initializers.get(gate_kernel_initializer)
        self.expert_kernel_regularizer = regularizers.get(expert_kernel_regularizer)
        self.gate_kernel_regularizer = regularizers.get(gate_kernel_regularizer)
        self.expert_kernel_constraint = constraints.get(expert_kernel_constraint)
        self.gate_kernel_constraint = constraints.get(gate_kernel_constraint)

        # Activation parameter
        self.expert_activation = activations.get(expert_activation)
        self.gate_activation = activations.get(gate_activation)

        # Bias parameter
        self.expert_bias = None
        self.gate_bias = None
        self.use_expert_bias = use_expert_bias
        self.use_gate_bias = use_gate_bias
        self.expert_bias_initializer = initializers.get(expert_bias_initializer)
        self.gate_bias_initializer = initializers.get(gate_bias_initializer)
        self.expert_bias_regularizer = regularizers.get(expert_bias_regularizer)
        self.gate_bias_regularizer = regularizers.get(gate_bias_regularizer)
        self.expert_bias_constraint = constraints.get(expert_bias_constraint)
        self.gate_bias_constraint = constraints.get(gate_bias_constraint)

        # Activity parameter
        self.activity_regularizer = regularizers.get(activity_regularizer)

        # Keras parameter
        self.input_spec = InputSpec(min_ndim=2)
        self.supports_masking = True

        super(MMoE, self).__init__(**kwargs)

    def build(self, input_shape):
        """
        Method for creating the layer weights.
        :param input_shape: Keras tensor (future input to layer)
                            or list/tuple of Keras tensors to reference
                            for weight shape computations
        """
        assert input_shape is not None and len(input_shape) >= 2

        input_dimension = input_shape[-1]

        # Initialize expert weights (number of input features * number of units per expert * number of experts)
        self.expert_kernels = self.add_weight(
            name='expert_kernel',
            shape=(input_dimension, self.units, self.num_experts),
            initializer=self.expert_kernel_initializer,
            regularizer=self.expert_kernel_regularizer,
            constraint=self.expert_kernel_constraint,
        )

        # Initialize expert bias (number of units per expert * number of experts)
        if self.use_expert_bias:
            self.expert_bias = self.add_weight(
                name='expert_bias',
                shape=(self.units, self.num_experts),
                initializer=self.expert_bias_initializer,
                regularizer=self.expert_bias_regularizer,
                constraint=self.expert_bias_constraint,
            )

        # Initialize gate weights (number of input features * number of experts * number of tasks)
        self.gate_kernels = [self.add_weight(
            name='gate_kernel_task_{}'.format(i),
            shape=(input_dimension, self.num_experts),
            initializer=self.gate_kernel_initializer,
            regularizer=self.gate_kernel_regularizer,
            constraint=self.gate_kernel_constraint
        ) for i in range(self.num_tasks)]

        # Initialize gate bias (number of experts * number of tasks)
        if self.use_gate_bias:
            self.gate_bias = [self.add_weight(
                name='gate_bias_task_{}'.format(i),
                shape=(self.num_experts,),
                initializer=self.gate_bias_initializer,
                regularizer=self.gate_bias_regularizer,
                constraint=self.gate_bias_constraint
            ) for i in range(self.num_tasks)]

        self.input_spec = InputSpec(min_ndim=2, axes={-1: input_dimension})

        super(MMoE, self).build(input_shape)

    def call(self, inputs, **kwargs):
        """
        Method for the forward function of the layer.
        :param inputs: Input tensor
        :param kwargs: Additional keyword arguments for the base method
        :return: A tensor
        """
        gate_outputs = []
        final_outputs = []

        # f_{i}(x) = activation(W_{i} * x + b), where activation is ReLU according to the paper
        expert_outputs = tf.tensordot(a=inputs, b=self.expert_kernels, axes=1)
        # Add the bias term to the expert weights if necessary
        if self.use_expert_bias:
            expert_outputs = K.bias_add(x=expert_outputs, bias=self.expert_bias)
        expert_outputs = self.expert_activation(expert_outputs)

        # g^{k}(x) = activation(W_{gk} * x + b), where activation is softmax according to the paper
        for index, gate_kernel in enumerate(self.gate_kernels):
            gate_output = K.dot(x=inputs, y=gate_kernel)
            # Add the bias term to the gate weights if necessary
            if self.use_gate_bias:
                gate_output = K.bias_add(x=gate_output, bias=self.gate_bias[index])
            gate_output = self.gate_activation(gate_output)
            gate_outputs.append(gate_output)

        # f^{k}(x) = sum_{i=1}^{n}(g^{k}(x)_{i} * f_{i}(x))
        for gate_output in gate_outputs:
            expanded_gate_output = K.expand_dims(gate_output, axis=1)
            weighted_expert_output = expert_outputs * K.repeat_elements(expanded_gate_output, self.units, axis=1)
            final_outputs.append(K.sum(weighted_expert_output, axis=2))

        return final_outputs

    def compute_output_shape(self, input_shape):
        """
        Method for computing the output shape of the MMoE layer.
        :param input_shape: Shape tuple (tuple of integers)
        :return: List of input shape tuple where the size of the list is equal to the number of tasks
        """
        assert input_shape is not None and len(input_shape) >= 2

        output_shape = list(input_shape)
        output_shape[-1] = self.units
        output_shape = tuple(output_shape)

        return [output_shape for _ in range(self.num_tasks)]

    def get_config(self):
        """
        Method for returning the configuration of the MMoE layer.
        :return: Config dictionary
        """
        config = {
            'units': self.units,
            'num_experts': self.num_experts,
            'num_tasks': self.num_tasks,
            'use_expert_bias': self.use_expert_bias,
            'use_gate_bias': self.use_gate_bias,
            'expert_activation': activations.serialize(self.expert_activation),
            'gate_activation': activations.serialize(self.gate_activation),
            'expert_bias_initializer': initializers.serialize(self.expert_bias_initializer),
            'gate_bias_initializer': initializers.serialize(self.gate_bias_initializer),
            'expert_bias_regularizer': regularizers.serialize(self.expert_bias_regularizer),
            'gate_bias_regularizer': regularizers.serialize(self.gate_bias_regularizer),
            'expert_bias_constraint': constraints.serialize(self.expert_bias_constraint),
            'gate_bias_constraint': constraints.serialize(self.gate_bias_constraint),
            'expert_kernel_initializer': initializers.serialize(self.expert_kernel_initializer),
            'gate_kernel_initializer': initializers.serialize(self.gate_kernel_initializer),
            'expert_kernel_regularizer': regularizers.serialize(self.expert_kernel_regularizer),
            'gate_kernel_regularizer': regularizers.serialize(self.gate_kernel_regularizer),
            'expert_kernel_constraint': constraints.serialize(self.expert_kernel_constraint),
            'gate_kernel_constraint': constraints.serialize(self.gate_kernel_constraint),
            'activity_regularizer': regularizers.serialize(self.activity_regularizer)
        }
        base_config = super(MMoE, self).get_config()

        return dict(list(base_config.items()) + list(config.items()))

# %%
"""
Multi-gate Mixture-of-Experts demo with census income data.
Copyright (c) 2018 Drawbridge, Inc
Licensed under the MIT License (see LICENSE for details)
Written by Peizhou Liao
"""

import random

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import VarianceScaling
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# from mmoe import MMoE

SEED = 1

# Fix numpy seed for reproducibility
np.random.seed(SEED)

# Fix random seed for reproducibility
random.seed(SEED)

# Fix TensorFlow graph-level seed for reproducibility
tf.random.set_seed(SEED)

def data_preparation():
    # Synthetic data parameters
    num_dimension = 100
    num_row = 12000
    c = 0.3
    rho = 0.8
    m = 5

    # Initialize vectors u1, u2, w1, and w2 according to the paper
    mu1 = np.random.normal(size=num_dimension)
    mu1 = (mu1 - np.mean(mu1)) / (np.std(mu1) * np.sqrt(num_dimension))
    mu2 = np.random.normal(size=num_dimension)
    mu2 -= mu2.dot(mu1) * mu1
    mu2 /= np.linalg.norm(mu2)
    w1 = c * mu1
    w2 = c * (rho * mu1 + np.sqrt(1. - rho ** 2) * mu2)

    # Feature and label generation
    alpha = np.random.normal(size=m)
    beta = np.random.normal(size=m)
    y0 = []
    y1 = []
    X = []

    for i in range(num_row):
        x = np.random.normal(size=num_dimension)
        X.append(x)
        num1 = w1.dot(x)
        num2 = w2.dot(x)
        comp1, comp2 = 0.0, 0.0

        for j in range(m):
            comp1 += np.sin(alpha[j] * num1 + beta[j])
            comp2 += np.sin(alpha[j] * num2 + beta[j])

        y0.append(num1 + comp1 + np.random.normal(scale=0.1, size=1))
        y1.append(num2 + comp2 + np.random.normal(scale=0.1, size=1))

    X = np.array(X)
    y0 = np.array(y0)
    y1 = np.array(y1)
    data = pd.DataFrame(
        data=X,
        index=range(X.shape[0]),
        columns=['x{}'.format(it) for it in range(X.shape[1])]
    )

    train_data = data.iloc[0:10000]
    train_label = [y0[0:10000], y1[0:10000]]
    validation_data = data.iloc[10000:11000]
    validation_label = [y0[10000:11000], y1[10000:11000]]
    test_data = data.iloc[11000:]
    test_label = [y0[11000:], y1[11000:]]

    return train_data, train_label, validation_data, validation_label, test_data, test_label

def main():
    # Load the data
    train_data, train_label, validation_data, validation_label, test_data, test_label = data_preparation()
    num_features = train_data.shape[1]

    print('Training data shape = {}'.format(train_data.shape))
    print('Validation data shape = {}'.format(validation_data.shape))
    print('Test data shape = {}'.format(test_data.shape))

    # Set up the input layer
    input_layer = Input(shape=(num_features,))

    # Set up MMoE layer
    mmoe_layers = MMoE(
        units=16,
        num_experts=8,
        num_tasks=2
    )(input_layer)

    output_layers = []

    output_info = ['y0', 'y1']

    # Build tower layer from MMoE layer
    for index, task_layer in enumerate(mmoe_layers):
        tower_layer = Dense(
            units=8,
            activation='relu',
            kernel_initializer=VarianceScaling())(task_layer)
        output_layer = Dense(
            units=1,
            name=output_info[index],
            activation='linear',
            kernel_initializer=VarianceScaling())(tower_layer)
        output_layers.append(output_layer)

    # Compile model
    model = Model(inputs=[input_layer], outputs=output_layers)
    learning_rates = [1e-4, 1e-3, 1e-2]
    adam_optimizer = Adam(learning_rate=learning_rates[0])
    model.compile(
        loss={'y0': 'mean_squared_error', 'y1': 'mean_squared_error'},
        optimizer=adam_optimizer,
        metrics=[metrics.mae]
    )

    # Print out model architecture summary
    model.summary()

    # Train the model
    model.fit(
        # x = np.stack(train_data, axis=0),  
        x=train_data,
        y=train_label,
        validation_data=(validation_data, validation_label),
        epochs=100
    )


if __name__ == '__main__':
    main()
# Out:
# Training data shape = (10000, 100)
# Validation data shape = (1000, 100)
# Test data shape = (1000, 100)
# Model: "model_30"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_31 (InputLayer)           [(None, 100)]        0
# __________________________________________________________________________________________________
# m_mo_e_30 (MMoE)                [(None, 16), (None,  14544       input_31[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 8)            136         m_mo_e_30[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 8)            136         m_mo_e_30[0][1]
# __________________________________________________________________________________________________
# y0 (Dense)                      (None, 1)            9           dense_60[0][0]
# __________________________________________________________________________________________________
# y1 (Dense)                      (None, 1)            9           dense_61[0][0]
# ==================================================================================================
# Total params: 14,834
# Trainable params: 14,834
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 313/313 [==============================] - 2s 3ms/step - loss: 12.9591 - y0_loss: 6.7883 - y1_loss: 6.1708 - y0_mean_absolute_error: 2.5392 - y1_mean_absolute_error: 2.4167 - val_loss: 11.5456 - val_y0_loss: 6.2080 - val_y1_loss: 5.3376 - val_y0_mean_absolute_error: 2.4244 - val_y1_mean_absolute_error: 2.2387
# Epoch 2/100
# 313/313 [==============================] - 1s 2ms/step - loss: 9.8250 - y0_loss: 5.5522 - y1_loss: 4.2728 - y0_mean_absolute_error: 2.2851 - y1_mean_absolute_error: 1.9890 - val_loss: 7.8688 - val_y0_loss: 4.7283 - val_y1_loss: 3.1405 - val_y0_mean_absolute_error: 2.1034 - val_y1_mean_absolute_error: 1.6866
# Epoch 3/100
# 313/313 [==============================] - 1s 2ms/step - loss: 5.7471 - y0_loss: 3.7576 - y1_loss: 1.9895 - y0_mean_absolute_error: 1.8562 - y1_mean_absolute_error: 1.2990 - val_loss: 3.8417 - val_y0_loss: 2.7611 - val_y1_loss: 1.0806 - val_y0_mean_absolute_error: 1.5784 - val_y1_mean_absolute_error: 0.9226
# Epoch 4/100
# 313/313 [==============================] - 1s 2ms/step - loss: 2.5261 - y0_loss: 1.8682 - y1_loss: 0.6579 - y0_mean_absolute_error: 1.2598 - y1_mean_absolute_error: 0.6829 - val_loss: 1.7259 - val_y0_loss: 1.1981 - val_y1_loss: 0.5279 - val_y0_mean_absolute_error: 0.9837 - val_y1_mean_absolute_error: 0.5944
# Epoch 5/100
# 313/313 [==============================] - 1s 2ms/step - loss: 1.2436 - y0_loss: 0.7928 - y1_loss: 0.4509 - y0_mean_absolute_error: 0.7727 - y1_mean_absolute_error: 0.5376 - val_loss: 1.0278 - val_y0_loss: 0.5859 - val_y1_loss: 0.4420 - val_y0_mean_absolute_error: 0.6564 - val_y1_mean_absolute_error: 0.5341
# Epoch 6/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.8485 - y0_loss: 0.4705 - y1_loss: 0.3781 - y0_mean_absolute_error: 0.5709 - y1_mean_absolute_error: 0.4891 - val_loss: 0.8107 - val_y0_loss: 0.4321 - val_y1_loss: 0.3786 - val_y0_mean_absolute_error: 0.5446 - val_y1_mean_absolute_error: 0.4950
# Epoch 7/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.6881 - y0_loss: 0.3725 - y1_loss: 0.3156 - y0_mean_absolute_error: 0.4982 - y1_mean_absolute_error: 0.4479 - val_loss: 0.6915 - val_y0_loss: 0.3672 - val_y1_loss: 0.3243 - val_y0_mean_absolute_error: 0.4945 - val_y1_mean_absolute_error: 0.4576
# Epoch 8/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5753 - y0_loss: 0.3112 - y1_loss: 0.2640 - y0_mean_absolute_error: 0.4524 - y1_mean_absolute_error: 0.4092 - val_loss: 0.5970 - val_y0_loss: 0.3184 - val_y1_loss: 0.2786 - val_y0_mean_absolute_error: 0.4584 - val_y1_mean_absolute_error: 0.4239
# Epoch 9/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4823 - y0_loss: 0.2610 - y1_loss: 0.2213 - y0_mean_absolute_error: 0.4137 - y1_mean_absolute_error: 0.3752 - val_loss: 0.5164 - val_y0_loss: 0.2765 - val_y1_loss: 0.2399 - val_y0_mean_absolute_error: 0.4271 - val_y1_mean_absolute_error: 0.3920
# Epoch 10/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4038 - y0_loss: 0.2169 - y1_loss: 0.1869 - y0_mean_absolute_error: 0.3771 - y1_mean_absolute_error: 0.3447 - val_loss: 0.4459 - val_y0_loss: 0.2383 - val_y1_loss: 0.2076 - val_y0_mean_absolute_error: 0.3964 - val_y1_mean_absolute_error: 0.3624
# Epoch 11/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3402 - y0_loss: 0.1814 - y1_loss: 0.1588 - y0_mean_absolute_error: 0.3446 - y1_mean_absolute_error: 0.3176 - val_loss: 0.3875 - val_y0_loss: 0.2068 - val_y1_loss: 0.1807 - val_y0_mean_absolute_error: 0.3678 - val_y1_mean_absolute_error: 0.3364
# Epoch 12/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2894 - y0_loss: 0.1529 - y1_loss: 0.1365 - y0_mean_absolute_error: 0.3157 - y1_mean_absolute_error: 0.2943 - val_loss: 0.3396 - val_y0_loss: 0.1806 - val_y1_loss: 0.1589 - val_y0_mean_absolute_error: 0.3424 - val_y1_mean_absolute_error: 0.3130
# Epoch 13/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2493 - y0_loss: 0.1306 - y1_loss: 0.1188 - y0_mean_absolute_error: 0.2905 - y1_mean_absolute_error: 0.2737 - val_loss: 0.3007 - val_y0_loss: 0.1595 - val_y1_loss: 0.1413 - val_y0_mean_absolute_error: 0.3211 - val_y1_mean_absolute_error: 0.2961
# Epoch 14/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2175 - y0_loss: 0.1129 - y1_loss: 0.1046 - y0_mean_absolute_error: 0.2690 - y1_mean_absolute_error: 0.2565 - val_loss: 0.2697 - val_y0_loss: 0.1424 - val_y1_loss: 0.1273 - val_y0_mean_absolute_error: 0.3026 - val_y1_mean_absolute_error: 0.2788
# Epoch 15/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1924 - y0_loss: 0.0990 - y1_loss: 0.0934 - y0_mean_absolute_error: 0.2508 - y1_mean_absolute_error: 0.2416 - val_loss: 0.2436 - val_y0_loss: 0.1276 - val_y1_loss: 0.1160 - val_y0_mean_absolute_error: 0.2856 - val_y1_mean_absolute_error: 0.2654
# Epoch 16/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1726 - y0_loss: 0.0877 - y1_loss: 0.0849 - y0_mean_absolute_error: 0.2350 - y1_mean_absolute_error: 0.2297 - val_loss: 0.2227 - val_y0_loss: 0.1158 - val_y1_loss: 0.1069 - val_y0_mean_absolute_error: 0.2707 - val_y1_mean_absolute_error: 0.2533
# Epoch 17/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1565 - y0_loss: 0.0785 - y1_loss: 0.0780 - y0_mean_absolute_error: 0.2212 - y1_mean_absolute_error: 0.2193 - val_loss: 0.2044 - val_y0_loss: 0.1053 - val_y1_loss: 0.0991 - val_y0_mean_absolute_error: 0.2566 - val_y1_mean_absolute_error: 0.2435
# Epoch 18/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1430 - y0_loss: 0.0707 - y1_loss: 0.0723 - y0_mean_absolute_error: 0.2091 - y1_mean_absolute_error: 0.2105 - val_loss: 0.1893 - val_y0_loss: 0.0962 - val_y1_loss: 0.0931 - val_y0_mean_absolute_error: 0.2454 - val_y1_mean_absolute_error: 0.2351
# Epoch 19/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1315 - y0_loss: 0.0638 - y1_loss: 0.0677 - y0_mean_absolute_error: 0.1976 - y1_mean_absolute_error: 0.2033 - val_loss: 0.1760 - val_y0_loss: 0.0882 - val_y1_loss: 0.0878 - val_y0_mean_absolute_error: 0.2358 - val_y1_mean_absolute_error: 0.2272
# Epoch 20/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1213 - y0_loss: 0.0578 - y1_loss: 0.0636 - y0_mean_absolute_error: 0.1879 - y1_mean_absolute_error: 0.1965 - val_loss: 0.1643 - val_y0_loss: 0.0811 - val_y1_loss: 0.0832 - val_y0_mean_absolute_error: 0.2256 - val_y1_mean_absolute_error: 0.2205
# Epoch 21/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1120 - y0_loss: 0.0522 - y1_loss: 0.0598 - y0_mean_absolute_error: 0.1784 - y1_mean_absolute_error: 0.1903 - val_loss: 0.1539 - val_y0_loss: 0.0748 - val_y1_loss: 0.0791 - val_y0_mean_absolute_error: 0.2168 - val_y1_mean_absolute_error: 0.2136
# Epoch 22/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1032 - y0_loss: 0.0472 - y1_loss: 0.0560 - y0_mean_absolute_error: 0.1695 - y1_mean_absolute_error: 0.1838 - val_loss: 0.1441 - val_y0_loss: 0.0692 - val_y1_loss: 0.0750 - val_y0_mean_absolute_error: 0.2088 - val_y1_mean_absolute_error: 0.2074
# Epoch 23/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0949 - y0_loss: 0.0427 - y1_loss: 0.0522 - y0_mean_absolute_error: 0.1612 - y1_mean_absolute_error: 0.1772 - val_loss: 0.1349 - val_y0_loss: 0.0639 - val_y1_loss: 0.0710 - val_y0_mean_absolute_error: 0.2010 - val_y1_mean_absolute_error: 0.2018
# Epoch 24/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0867 - y0_loss: 0.0384 - y1_loss: 0.0483 - y0_mean_absolute_error: 0.1531 - y1_mean_absolute_error: 0.1705 - val_loss: 0.1250 - val_y0_loss: 0.0587 - val_y1_loss: 0.0664 - val_y0_mean_absolute_error: 0.1924 - val_y1_mean_absolute_error: 0.1958
# Epoch 25/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0789 - y0_loss: 0.0346 - y1_loss: 0.0443 - y0_mean_absolute_error: 0.1457 - y1_mean_absolute_error: 0.1634 - val_loss: 0.1163 - val_y0_loss: 0.0544 - val_y1_loss: 0.0619 - val_y0_mean_absolute_error: 0.1857 - val_y1_mean_absolute_error: 0.1897
# Epoch 26/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0714 - y0_loss: 0.0312 - y1_loss: 0.0402 - y0_mean_absolute_error: 0.1385 - y1_mean_absolute_error: 0.1560 - val_loss: 0.1086 - val_y0_loss: 0.0509 - val_y1_loss: 0.0577 - val_y0_mean_absolute_error: 0.1804 - val_y1_mean_absolute_error: 0.1831
# Epoch 27/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0647 - y0_loss: 0.0282 - y1_loss: 0.0365 - y0_mean_absolute_error: 0.1319 - y1_mean_absolute_error: 0.1487 - val_loss: 0.1009 - val_y0_loss: 0.0475 - val_y1_loss: 0.0534 - val_y0_mean_absolute_error: 0.1756 - val_y1_mean_absolute_error: 0.1772
# Epoch 28/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0587 - y0_loss: 0.0257 - y1_loss: 0.0330 - y0_mean_absolute_error: 0.1264 - y1_mean_absolute_error: 0.1418 - val_loss: 0.0940 - val_y0_loss: 0.0444 - val_y1_loss: 0.0496 - val_y0_mean_absolute_error: 0.1693 - val_y1_mean_absolute_error: 0.1705
# Epoch 29/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0534 - y0_loss: 0.0235 - y1_loss: 0.0299 - y0_mean_absolute_error: 0.1212 - y1_mean_absolute_error: 0.1355 - val_loss: 0.0882 - val_y0_loss: 0.0418 - val_y1_loss: 0.0464 - val_y0_mean_absolute_error: 0.1643 - val_y1_mean_absolute_error: 0.1655
# Epoch 30/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0490 - y0_loss: 0.0218 - y1_loss: 0.0272 - y0_mean_absolute_error: 0.1168 - y1_mean_absolute_error: 0.1296 - val_loss: 0.0823 - val_y0_loss: 0.0395 - val_y1_loss: 0.0428 - val_y0_mean_absolute_error: 0.1592 - val_y1_mean_absolute_error: 0.1585
# Epoch 31/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0453 - y0_loss: 0.0203 - y1_loss: 0.0250 - y0_mean_absolute_error: 0.1128 - y1_mean_absolute_error: 0.1242 - val_loss: 0.0780 - val_y0_loss: 0.0375 - val_y1_loss: 0.0406 - val_y0_mean_absolute_error: 0.1553 - val_y1_mean_absolute_error: 0.1550
# Epoch 32/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0420 - y0_loss: 0.0189 - y1_loss: 0.0231 - y0_mean_absolute_error: 0.1091 - y1_mean_absolute_error: 0.1197 - val_loss: 0.0747 - val_y0_loss: 0.0363 - val_y1_loss: 0.0385 - val_y0_mean_absolute_error: 0.1531 - val_y1_mean_absolute_error: 0.1505
# Epoch 33/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0393 - y0_loss: 0.0178 - y1_loss: 0.0215 - y0_mean_absolute_error: 0.1058 - y1_mean_absolute_error: 0.1155 - val_loss: 0.0710 - val_y0_loss: 0.0346 - val_y1_loss: 0.0364 - val_y0_mean_absolute_error: 0.1490 - val_y1_mean_absolute_error: 0.1462
# Epoch 34/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0370 - y0_loss: 0.0168 - y1_loss: 0.0202 - y0_mean_absolute_error: 0.1027 - y1_mean_absolute_error: 0.1121 - val_loss: 0.0681 - val_y0_loss: 0.0334 - val_y1_loss: 0.0348 - val_y0_mean_absolute_error: 0.1469 - val_y1_mean_absolute_error: 0.1433
# Epoch 35/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0349 - y0_loss: 0.0159 - y1_loss: 0.0190 - y0_mean_absolute_error: 0.1000 - y1_mean_absolute_error: 0.1088 - val_loss: 0.0659 - val_y0_loss: 0.0324 - val_y1_loss: 0.0336 - val_y0_mean_absolute_error: 0.1441 - val_y1_mean_absolute_error: 0.1409
# Epoch 36/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0331 - y0_loss: 0.0151 - y1_loss: 0.0180 - y0_mean_absolute_error: 0.0975 - y1_mean_absolute_error: 0.1059 - val_loss: 0.0639 - val_y0_loss: 0.0313 - val_y1_loss: 0.0326 - val_y0_mean_absolute_error: 0.1420 - val_y1_mean_absolute_error: 0.1395
# Epoch 37/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0315 - y0_loss: 0.0144 - y1_loss: 0.0171 - y0_mean_absolute_error: 0.0953 - y1_mean_absolute_error: 0.1035 - val_loss: 0.0620 - val_y0_loss: 0.0304 - val_y1_loss: 0.0316 - val_y0_mean_absolute_error: 0.1394 - val_y1_mean_absolute_error: 0.1381
# Epoch 38/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0301 - y0_loss: 0.0137 - y1_loss: 0.0164 - y0_mean_absolute_error: 0.0931 - y1_mean_absolute_error: 0.1012 - val_loss: 0.0603 - val_y0_loss: 0.0297 - val_y1_loss: 0.0306 - val_y0_mean_absolute_error: 0.1387 - val_y1_mean_absolute_error: 0.1352
# Epoch 39/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0289 - y0_loss: 0.0132 - y1_loss: 0.0157 - y0_mean_absolute_error: 0.0912 - y1_mean_absolute_error: 0.0991 - val_loss: 0.0586 - val_y0_loss: 0.0288 - val_y1_loss: 0.0297 - val_y0_mean_absolute_error: 0.1367 - val_y1_mean_absolute_error: 0.1335
# Epoch 40/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0277 - y0_loss: 0.0126 - y1_loss: 0.0150 - y0_mean_absolute_error: 0.0892 - y1_mean_absolute_error: 0.0969 - val_loss: 0.0573 - val_y0_loss: 0.0282 - val_y1_loss: 0.0291 - val_y0_mean_absolute_error: 0.1348 - val_y1_mean_absolute_error: 0.1325
# Epoch 41/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0266 - y0_loss: 0.0122 - y1_loss: 0.0145 - y0_mean_absolute_error: 0.0876 - y1_mean_absolute_error: 0.0952 - val_loss: 0.0559 - val_y0_loss: 0.0276 - val_y1_loss: 0.0283 - val_y0_mean_absolute_error: 0.1335 - val_y1_mean_absolute_error: 0.1311
# Epoch 42/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0257 - y0_loss: 0.0117 - y1_loss: 0.0140 - y0_mean_absolute_error: 0.0860 - y1_mean_absolute_error: 0.0935 - val_loss: 0.0544 - val_y0_loss: 0.0268 - val_y1_loss: 0.0276 - val_y0_mean_absolute_error: 0.1315 - val_y1_mean_absolute_error: 0.1297
# Epoch 43/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0248 - y0_loss: 0.0113 - y1_loss: 0.0135 - y0_mean_absolute_error: 0.0847 - y1_mean_absolute_error: 0.0917 - val_loss: 0.0535 - val_y0_loss: 0.0263 - val_y1_loss: 0.0271 - val_y0_mean_absolute_error: 0.1303 - val_y1_mean_absolute_error: 0.1289
# Epoch 44/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0240 - y0_loss: 0.0109 - y1_loss: 0.0131 - y0_mean_absolute_error: 0.0832 - y1_mean_absolute_error: 0.0903 - val_loss: 0.0526 - val_y0_loss: 0.0260 - val_y1_loss: 0.0267 - val_y0_mean_absolute_error: 0.1291 - val_y1_mean_absolute_error: 0.1280
# Epoch 45/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0233 - y0_loss: 0.0107 - y1_loss: 0.0127 - y0_mean_absolute_error: 0.0821 - y1_mean_absolute_error: 0.0890 - val_loss: 0.0520 - val_y0_loss: 0.0257 - val_y1_loss: 0.0263 - val_y0_mean_absolute_error: 0.1284 - val_y1_mean_absolute_error: 0.1269
# Epoch 46/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0226 - y0_loss: 0.0103 - y1_loss: 0.0123 - y0_mean_absolute_error: 0.0808 - y1_mean_absolute_error: 0.0877 - val_loss: 0.0515 - val_y0_loss: 0.0253 - val_y1_loss: 0.0262 - val_y0_mean_absolute_error: 0.1279 - val_y1_mean_absolute_error: 0.1270
# Epoch 47/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0220 - y0_loss: 0.0101 - y1_loss: 0.0120 - y0_mean_absolute_error: 0.0798 - y1_mean_absolute_error: 0.0864 - val_loss: 0.0505 - val_y0_loss: 0.0249 - val_y1_loss: 0.0255 - val_y0_mean_absolute_error: 0.1266 - val_y1_mean_absolute_error: 0.1250
# Epoch 48/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0214 - y0_loss: 0.0097 - y1_loss: 0.0116 - y0_mean_absolute_error: 0.0784 - y1_mean_absolute_error: 0.0852 - val_loss: 0.0499 - val_y0_loss: 0.0246 - val_y1_loss: 0.0253 - val_y0_mean_absolute_error: 0.1254 - val_y1_mean_absolute_error: 0.1247
# Epoch 49/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0209 - y0_loss: 0.0095 - y1_loss: 0.0113 - y0_mean_absolute_error: 0.0777 - y1_mean_absolute_error: 0.0841 - val_loss: 0.0492 - val_y0_loss: 0.0243 - val_y1_loss: 0.0249 - val_y0_mean_absolute_error: 0.1246 - val_y1_mean_absolute_error: 0.1236
# Epoch 50/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0204 - y0_loss: 0.0093 - y1_loss: 0.0111 - y0_mean_absolute_error: 0.0767 - y1_mean_absolute_error: 0.0831 - val_loss: 0.0490 - val_y0_loss: 0.0242 - val_y1_loss: 0.0249 - val_y0_mean_absolute_error: 0.1244 - val_y1_mean_absolute_error: 0.1235
# Epoch 51/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0199 - y0_loss: 0.0091 - y1_loss: 0.0108 - y0_mean_absolute_error: 0.0760 - y1_mean_absolute_error: 0.0820 - val_loss: 0.0482 - val_y0_loss: 0.0239 - val_y1_loss: 0.0244 - val_y0_mean_absolute_error: 0.1239 - val_y1_mean_absolute_error: 0.1226
# Epoch 52/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0194 - y0_loss: 0.0089 - y1_loss: 0.0106 - y0_mean_absolute_error: 0.0749 - y1_mean_absolute_error: 0.0811 - val_loss: 0.0478 - val_y0_loss: 0.0236 - val_y1_loss: 0.0243 - val_y0_mean_absolute_error: 0.1233 - val_y1_mean_absolute_error: 0.1225
# Epoch 53/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0190 - y0_loss: 0.0087 - y1_loss: 0.0103 - y0_mean_absolute_error: 0.0742 - y1_mean_absolute_error: 0.0804 - val_loss: 0.0476 - val_y0_loss: 0.0235 - val_y1_loss: 0.0241 - val_y0_mean_absolute_error: 0.1229 - val_y1_mean_absolute_error: 0.1221
# Epoch 54/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0186 - y0_loss: 0.0085 - y1_loss: 0.0101 - y0_mean_absolute_error: 0.0735 - y1_mean_absolute_error: 0.0794 - val_loss: 0.0469 - val_y0_loss: 0.0232 - val_y1_loss: 0.0237 - val_y0_mean_absolute_error: 0.1218 - val_y1_mean_absolute_error: 0.1211
# Epoch 55/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0182 - y0_loss: 0.0084 - y1_loss: 0.0099 - y0_mean_absolute_error: 0.0727 - y1_mean_absolute_error: 0.0786 - val_loss: 0.0469 - val_y0_loss: 0.0231 - val_y1_loss: 0.0237 - val_y0_mean_absolute_error: 0.1216 - val_y1_mean_absolute_error: 0.1214
# Epoch 56/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0179 - y0_loss: 0.0082 - y1_loss: 0.0097 - y0_mean_absolute_error: 0.0721 - y1_mean_absolute_error: 0.0780 - val_loss: 0.0466 - val_y0_loss: 0.0230 - val_y1_loss: 0.0237 - val_y0_mean_absolute_error: 0.1216 - val_y1_mean_absolute_error: 0.1209
# Epoch 57/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0176 - y0_loss: 0.0081 - y1_loss: 0.0095 - y0_mean_absolute_error: 0.0714 - y1_mean_absolute_error: 0.0771 - val_loss: 0.0464 - val_y0_loss: 0.0229 - val_y1_loss: 0.0236 - val_y0_mean_absolute_error: 0.1214 - val_y1_mean_absolute_error: 0.1210
# Epoch 58/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0173 - y0_loss: 0.0079 - y1_loss: 0.0094 - y0_mean_absolute_error: 0.0708 - y1_mean_absolute_error: 0.0765 - val_loss: 0.0459 - val_y0_loss: 0.0225 - val_y1_loss: 0.0233 - val_y0_mean_absolute_error: 0.1203 - val_y1_mean_absolute_error: 0.1198
# Epoch 59/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0170 - y0_loss: 0.0078 - y1_loss: 0.0092 - y0_mean_absolute_error: 0.0703 - y1_mean_absolute_error: 0.0760 - val_loss: 0.0458 - val_y0_loss: 0.0225 - val_y1_loss: 0.0233 - val_y0_mean_absolute_error: 0.1199 - val_y1_mean_absolute_error: 0.1202
# Epoch 60/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0167 - y0_loss: 0.0077 - y1_loss: 0.0090 - y0_mean_absolute_error: 0.0698 - y1_mean_absolute_error: 0.0752 - val_loss: 0.0455 - val_y0_loss: 0.0225 - val_y1_loss: 0.0231 - val_y0_mean_absolute_error: 0.1203 - val_y1_mean_absolute_error: 0.1193
# Epoch 61/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0165 - y0_loss: 0.0076 - y1_loss: 0.0089 - y0_mean_absolute_error: 0.0692 - y1_mean_absolute_error: 0.0745 - val_loss: 0.0451 - val_y0_loss: 0.0222 - val_y1_loss: 0.0230 - val_y0_mean_absolute_error: 0.1191 - val_y1_mean_absolute_error: 0.1191
# Epoch 62/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0162 - y0_loss: 0.0074 - y1_loss: 0.0088 - y0_mean_absolute_error: 0.0688 - y1_mean_absolute_error: 0.0740 - val_loss: 0.0451 - val_y0_loss: 0.0222 - val_y1_loss: 0.0229 - val_y0_mean_absolute_error: 0.1191 - val_y1_mean_absolute_error: 0.1194
# Epoch 63/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0160 - y0_loss: 0.0073 - y1_loss: 0.0086 - y0_mean_absolute_error: 0.0681 - y1_mean_absolute_error: 0.0734 - val_loss: 0.0449 - val_y0_loss: 0.0222 - val_y1_loss: 0.0227 - val_y0_mean_absolute_error: 0.1194 - val_y1_mean_absolute_error: 0.1190
# Epoch 64/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0157 - y0_loss: 0.0072 - y1_loss: 0.0085 - y0_mean_absolute_error: 0.0678 - y1_mean_absolute_error: 0.0729 - val_loss: 0.0449 - val_y0_loss: 0.0221 - val_y1_loss: 0.0228 - val_y0_mean_absolute_error: 0.1184 - val_y1_mean_absolute_error: 0.1193
# Epoch 65/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0155 - y0_loss: 0.0071 - y1_loss: 0.0084 - y0_mean_absolute_error: 0.0671 - y1_mean_absolute_error: 0.0725 - val_loss: 0.0445 - val_y0_loss: 0.0220 - val_y1_loss: 0.0225 - val_y0_mean_absolute_error: 0.1190 - val_y1_mean_absolute_error: 0.1185
# Epoch 66/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0153 - y0_loss: 0.0071 - y1_loss: 0.0082 - y0_mean_absolute_error: 0.0669 - y1_mean_absolute_error: 0.0717 - val_loss: 0.0446 - val_y0_loss: 0.0218 - val_y1_loss: 0.0227 - val_y0_mean_absolute_error: 0.1183 - val_y1_mean_absolute_error: 0.1190
# Epoch 67/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0151 - y0_loss: 0.0069 - y1_loss: 0.0081 - y0_mean_absolute_error: 0.0662 - y1_mean_absolute_error: 0.0713 - val_loss: 0.0445 - val_y0_loss: 0.0220 - val_y1_loss: 0.0225 - val_y0_mean_absolute_error: 0.1187 - val_y1_mean_absolute_error: 0.1188
# Epoch 68/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0149 - y0_loss: 0.0069 - y1_loss: 0.0080 - y0_mean_absolute_error: 0.0660 - y1_mean_absolute_error: 0.0709 - val_loss: 0.0444 - val_y0_loss: 0.0218 - val_y1_loss: 0.0226 - val_y0_mean_absolute_error: 0.1180 - val_y1_mean_absolute_error: 0.1189
# Epoch 69/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0147 - y0_loss: 0.0068 - y1_loss: 0.0079 - y0_mean_absolute_error: 0.0656 - y1_mean_absolute_error: 0.0704 - val_loss: 0.0445 - val_y0_loss: 0.0220 - val_y1_loss: 0.0225 - val_y0_mean_absolute_error: 0.1185 - val_y1_mean_absolute_error: 0.1187
# Epoch 70/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0145 - y0_loss: 0.0067 - y1_loss: 0.0078 - y0_mean_absolute_error: 0.0651 - y1_mean_absolute_error: 0.0700 - val_loss: 0.0439 - val_y0_loss: 0.0216 - val_y1_loss: 0.0222 - val_y0_mean_absolute_error: 0.1180 - val_y1_mean_absolute_error: 0.1177
# Epoch 71/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0144 - y0_loss: 0.0066 - y1_loss: 0.0077 - y0_mean_absolute_error: 0.0650 - y1_mean_absolute_error: 0.0695 - val_loss: 0.0438 - val_y0_loss: 0.0215 - val_y1_loss: 0.0223 - val_y0_mean_absolute_error: 0.1176 - val_y1_mean_absolute_error: 0.1181
# Epoch 72/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0142 - y0_loss: 0.0065 - y1_loss: 0.0076 - y0_mean_absolute_error: 0.0645 - y1_mean_absolute_error: 0.0692 - val_loss: 0.0438 - val_y0_loss: 0.0216 - val_y1_loss: 0.0222 - val_y0_mean_absolute_error: 0.1178 - val_y1_mean_absolute_error: 0.1179
# Epoch 73/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0141 - y0_loss: 0.0065 - y1_loss: 0.0076 - y0_mean_absolute_error: 0.0641 - y1_mean_absolute_error: 0.0687 - val_loss: 0.0438 - val_y0_loss: 0.0216 - val_y1_loss: 0.0222 - val_y0_mean_absolute_error: 0.1178 - val_y1_mean_absolute_error: 0.1182
# Epoch 74/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0139 - y0_loss: 0.0064 - y1_loss: 0.0075 - y0_mean_absolute_error: 0.0639 - y1_mean_absolute_error: 0.0685 - val_loss: 0.0438 - val_y0_loss: 0.0216 - val_y1_loss: 0.0222 - val_y0_mean_absolute_error: 0.1174 - val_y1_mean_absolute_error: 0.1178
# Epoch 75/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0138 - y0_loss: 0.0064 - y1_loss: 0.0074 - y0_mean_absolute_error: 0.0636 - y1_mean_absolute_error: 0.0679 - val_loss: 0.0434 - val_y0_loss: 0.0215 - val_y1_loss: 0.0219 - val_y0_mean_absolute_error: 0.1173 - val_y1_mean_absolute_error: 0.1172
# Epoch 76/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0136 - y0_loss: 0.0063 - y1_loss: 0.0073 - y0_mean_absolute_error: 0.0633 - y1_mean_absolute_error: 0.0675 - val_loss: 0.0433 - val_y0_loss: 0.0213 - val_y1_loss: 0.0220 - val_y0_mean_absolute_error: 0.1162 - val_y1_mean_absolute_error: 0.1176
# Epoch 77/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0134 - y0_loss: 0.0062 - y1_loss: 0.0072 - y0_mean_absolute_error: 0.0627 - y1_mean_absolute_error: 0.0673 - val_loss: 0.0434 - val_y0_loss: 0.0215 - val_y1_loss: 0.0219 - val_y0_mean_absolute_error: 0.1171 - val_y1_mean_absolute_error: 0.1178
# Epoch 78/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0133 - y0_loss: 0.0062 - y1_loss: 0.0071 - y0_mean_absolute_error: 0.0625 - y1_mean_absolute_error: 0.0668 - val_loss: 0.0433 - val_y0_loss: 0.0215 - val_y1_loss: 0.0218 - val_y0_mean_absolute_error: 0.1168 - val_y1_mean_absolute_error: 0.1172
# Epoch 79/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0132 - y0_loss: 0.0061 - y1_loss: 0.0071 - y0_mean_absolute_error: 0.0623 - y1_mean_absolute_error: 0.0664 - val_loss: 0.0434 - val_y0_loss: 0.0214 - val_y1_loss: 0.0219 - val_y0_mean_absolute_error: 0.1172 - val_y1_mean_absolute_error: 0.1176
# Epoch 80/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0131 - y0_loss: 0.0060 - y1_loss: 0.0070 - y0_mean_absolute_error: 0.0619 - y1_mean_absolute_error: 0.0664 - val_loss: 0.0431 - val_y0_loss: 0.0215 - val_y1_loss: 0.0217 - val_y0_mean_absolute_error: 0.1172 - val_y1_mean_absolute_error: 0.1171
# Epoch 81/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0129 - y0_loss: 0.0060 - y1_loss: 0.0069 - y0_mean_absolute_error: 0.0617 - y1_mean_absolute_error: 0.0659 - val_loss: 0.0432 - val_y0_loss: 0.0215 - val_y1_loss: 0.0217 - val_y0_mean_absolute_error: 0.1170 - val_y1_mean_absolute_error: 0.1172
# Epoch 82/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0128 - y0_loss: 0.0060 - y1_loss: 0.0068 - y0_mean_absolute_error: 0.0616 - y1_mean_absolute_error: 0.0653 - val_loss: 0.0432 - val_y0_loss: 0.0215 - val_y1_loss: 0.0217 - val_y0_mean_absolute_error: 0.1170 - val_y1_mean_absolute_error: 0.1165
# Epoch 83/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0127 - y0_loss: 0.0059 - y1_loss: 0.0068 - y0_mean_absolute_error: 0.0611 - y1_mean_absolute_error: 0.0652 - val_loss: 0.0430 - val_y0_loss: 0.0213 - val_y1_loss: 0.0217 - val_y0_mean_absolute_error: 0.1171 - val_y1_mean_absolute_error: 0.1171
# Epoch 84/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0126 - y0_loss: 0.0059 - y1_loss: 0.0067 - y0_mean_absolute_error: 0.0610 - y1_mean_absolute_error: 0.0648 - val_loss: 0.0430 - val_y0_loss: 0.0213 - val_y1_loss: 0.0217 - val_y0_mean_absolute_error: 0.1165 - val_y1_mean_absolute_error: 0.1167
# Epoch 85/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0125 - y0_loss: 0.0058 - y1_loss: 0.0066 - y0_mean_absolute_error: 0.0607 - y1_mean_absolute_error: 0.0645 - val_loss: 0.0431 - val_y0_loss: 0.0214 - val_y1_loss: 0.0217 - val_y0_mean_absolute_error: 0.1169 - val_y1_mean_absolute_error: 0.1174
# Epoch 86/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0123 - y0_loss: 0.0057 - y1_loss: 0.0066 - y0_mean_absolute_error: 0.0604 - y1_mean_absolute_error: 0.0643 - val_loss: 0.0430 - val_y0_loss: 0.0215 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1173 - val_y1_mean_absolute_error: 0.1168
# Epoch 87/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0123 - y0_loss: 0.0057 - y1_loss: 0.0065 - y0_mean_absolute_error: 0.0602 - y1_mean_absolute_error: 0.0641 - val_loss: 0.0431 - val_y0_loss: 0.0214 - val_y1_loss: 0.0216 - val_y0_mean_absolute_error: 0.1173 - val_y1_mean_absolute_error: 0.1171
# Epoch 88/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0121 - y0_loss: 0.0057 - y1_loss: 0.0065 - y0_mean_absolute_error: 0.0601 - y1_mean_absolute_error: 0.0637 - val_loss: 0.0430 - val_y0_loss: 0.0214 - val_y1_loss: 0.0216 - val_y0_mean_absolute_error: 0.1168 - val_y1_mean_absolute_error: 0.1171
# Epoch 89/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0120 - y0_loss: 0.0056 - y1_loss: 0.0064 - y0_mean_absolute_error: 0.0597 - y1_mean_absolute_error: 0.0635 - val_loss: 0.0428 - val_y0_loss: 0.0215 - val_y1_loss: 0.0214 - val_y0_mean_absolute_error: 0.1168 - val_y1_mean_absolute_error: 0.1165
# Epoch 90/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0119 - y0_loss: 0.0056 - y1_loss: 0.0064 - y0_mean_absolute_error: 0.0593 - y1_mean_absolute_error: 0.0632 - val_loss: 0.0432 - val_y0_loss: 0.0215 - val_y1_loss: 0.0217 - val_y0_mean_absolute_error: 0.1169 - val_y1_mean_absolute_error: 0.1177
# Epoch 91/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0118 - y0_loss: 0.0055 - y1_loss: 0.0063 - y0_mean_absolute_error: 0.0593 - y1_mean_absolute_error: 0.0628 - val_loss: 0.0430 - val_y0_loss: 0.0215 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1171 - val_y1_mean_absolute_error: 0.1167
# Epoch 92/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0117 - y0_loss: 0.0055 - y1_loss: 0.0063 - y0_mean_absolute_error: 0.0590 - y1_mean_absolute_error: 0.0627 - val_loss: 0.0430 - val_y0_loss: 0.0215 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1172 - val_y1_mean_absolute_error: 0.1172
# Epoch 93/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0116 - y0_loss: 0.0054 - y1_loss: 0.0062 - y0_mean_absolute_error: 0.0590 - y1_mean_absolute_error: 0.0624 - val_loss: 0.0432 - val_y0_loss: 0.0217 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1172 - val_y1_mean_absolute_error: 0.1169
# Epoch 94/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0115 - y0_loss: 0.0054 - y1_loss: 0.0061 - y0_mean_absolute_error: 0.0583 - y1_mean_absolute_error: 0.0619 - val_loss: 0.0431 - val_y0_loss: 0.0216 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1171 - val_y1_mean_absolute_error: 0.1173
# Epoch 95/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0115 - y0_loss: 0.0054 - y1_loss: 0.0061 - y0_mean_absolute_error: 0.0584 - y1_mean_absolute_error: 0.0619 - val_loss: 0.0430 - val_y0_loss: 0.0216 - val_y1_loss: 0.0214 - val_y0_mean_absolute_error: 0.1169 - val_y1_mean_absolute_error: 0.1168
# Epoch 96/100
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0113 - y0_loss: 0.0053 - y1_loss: 0.0060 - y0_mean_absolute_error: 0.0582 - y1_mean_absolute_error: 0.0615 - val_loss: 0.0430 - val_y0_loss: 0.0217 - val_y1_loss: 0.0213 - val_y0_mean_absolute_error: 0.1179 - val_y1_mean_absolute_error: 0.1164
# Epoch 97/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0113 - y0_loss: 0.0053 - y1_loss: 0.0060 - y0_mean_absolute_error: 0.0579 - y1_mean_absolute_error: 0.0612 - val_loss: 0.0433 - val_y0_loss: 0.0218 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1181 - val_y1_mean_absolute_error: 0.1174
# Epoch 98/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0112 - y0_loss: 0.0052 - y1_loss: 0.0059 - y0_mean_absolute_error: 0.0576 - y1_mean_absolute_error: 0.0612 - val_loss: 0.0436 - val_y0_loss: 0.0220 - val_y1_loss: 0.0216 - val_y0_mean_absolute_error: 0.1181 - val_y1_mean_absolute_error: 0.1179
# Epoch 99/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0111 - y0_loss: 0.0052 - y1_loss: 0.0059 - y0_mean_absolute_error: 0.0575 - y1_mean_absolute_error: 0.0610 - val_loss: 0.0434 - val_y0_loss: 0.0218 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1178 - val_y1_mean_absolute_error: 0.1174
# Epoch 100/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0110 - y0_loss: 0.0051 - y1_loss: 0.0059 - y0_mean_absolute_error: 0.0572 - y1_mean_absolute_error: 0.0606 - val_loss: 0.0438 - val_y0_loss: 0.0219 - val_y1_loss: 0.0219 - val_y0_mean_absolute_error: 0.1180 - val_y1_mean_absolute_error: 0.1184
